# %%
#import User libraries:

import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer
import numpy as np
import matplotlib.pyplot as plt

# %%
Read Our Data:

# %%
data=pd.read_csv(r"D:\Fast Food.csv")
data
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1    7/3/2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4    2/3/2023  Sugarcane juice  Beverages          25         6
# 4           5   10/2/2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
#Show First 10 Rows in The Data:
data.head(10)
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1    7/3/2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4    2/3/2023  Sugarcane juice  Beverages          25         6
# 4         5   10/2/2022  Sugarcane juice  Beverages          25         8
# 5         6  11/14/2022          Vadapav   Fastfood          20        10
# 6         7    5/3/2022  Sugarcane juice  Beverages          25         9
# 7         8  12/22/2022         Panipuri   Fastfood          20        14
# 8         9   6/10/2022         Panipuri   Fastfood          20         1
# 9        10   9/16/2022         Panipuri   Fastfood          20         5
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# ...

# %%
#Data Information:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %%
Data Cleaning:

# %%
data.isna().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
data['transaction_type'].value_counts()
# Out:
# Cash      476
# Online    417
# Name: transaction_type, dtype: int64

# %%
data['transaction_type'].describe()
# Out:
# count      893
# unique       2
# top       Cash
# freq       476
# Name: transaction_type, dtype: object

# %%
data['transaction_type'].fillna("Another",inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    1000 non-null   object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
 Analyse data:

# %%
data.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          275.230000
# std     288.819436    14.921744     4.413075          204.402979
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          900.000000

# %%
data['item_name'].value_counts()
# Out:
# Cold coffee        161
# Sugarcane juice    153
# Panipuri           150
# Frankie            139
# Aalopuri           134
# Vadapav            134
# Sandwich           129
# Name: item_name, dtype: int64

# %%
data['item_name'].value_counts().plot(kind='bar',facecolor="b",edgecolor="r")
plt.show()

# %%
data['item_name'].value_counts().plot(kind="pie",autopct="%1.1f%%",shadow=True)
plt.show()

# %%
data['item_name'].value_counts().plot(kind='barh')
plt.show()

# %%
data["item_type"].value_counts()
# Out:
# Fastfood     686
# Beverages    314
# Name: item_type, dtype: int64

# %%
data['item_type'].value_counts().plot(kind='bar',facecolor="r",edgecolor="w")
plt.show()

# %%
data.groupby(['item_type']).count()['item_name']
# Out:
# item_type
# Beverages    314
# Fastfood     686
# Name: item_name, dtype: int64

# %%
sns.countplot(x="item_type",hue="item_name",data=data)
plt.legend(loc="upper right",bbox_to_anchor=(1.4,1),title="item_name")

# %%
data[data['item_price']==60][:10]
# Out:
#      order_id       date item_name item_type  item_price  quantity  \
# 15         16  4/14/2022  Sandwich  Fastfood          60        11
# 22         23  5/26/2022  Sandwich  Fastfood          60         3
# 24         25  8/31/2022  Sandwich  Fastfood          60         1
# 39         40   2/5/2023  Sandwich  Fastfood          60         5
# 46         47  7/10/2022  Sandwich  Fastfood          60         7
# 47         48  2/23/2023  Sandwich  Fastfood          60        14
# 54         55   5/7/2022  Sandwich  Fastfood          60        10
# 62         63  12/1/2022  Sandwich  Fastfood          60         7
# 95         96  8/22/2022  Sandwich  Fastfood          60        15
# 106       107   2/7/2023  Sandwich  Fastfood          60         4
#
#      transaction_amount transaction_type received_by time_of_sale
# 15                  660          Another        Mrs.     Midnight
# 22                  180           Online         Mr.     Midnight
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='item_name',hue='item_price',data=data)
plt.legend(loc='upper left',bbox_to_anchor=(1,1),title='item_price')

# %%
data['quantity'].max()
# Out:
# 15

# %%
data[data['quantity']==15]
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 20         21  12/21/2022      Cold coffee  Beverages          40        15
# 50         51   5/16/2022          Frankie   Fastfood          50        15
# 85         86    3/9/2023         Aalopuri   Fastfood          20        15
# 89         90  10/29/2022          Vadapav   Fastfood          20        15
# ..        ...         ...              ...        ...         ...       ...
# 932       933   1/21/2023  Sugarcane juice  Beverages          25        15
# 938       939   2/19/2023          Vadapav   Fastfood          20        15
# 959       960   8/12/2022  Sugarcane juice  Beverages          25        15
# 967       968    8/9/2022      Cold coffee  Beverages          40        15
# 980       981   1/22/2023         Panipuri   Fastfood          20        15
#
# ...

# %%
print("this is 10 top of quantity with low price")
data[data['quantity']==15].sort_values(by='item_price',ascending=True)[:10]
# Out:
# this is 10 top of quantity with low price
#      order_id        date item_name item_type  item_price  quantity  \
# 1           2   8/23/2022   Vadapav  Fastfood          20        15
# 409       410  11/23/2022  Aalopuri  Fastfood          20        15
# 542       543   4/10/2022  Aalopuri  Fastfood          20        15
# 564       565   9/27/2022  Panipuri  Fastfood          20        15
# 589       590   3/27/2023  Panipuri  Fastfood          20        15
# 634       635    2/6/2023   Vadapav  Fastfood          20        15
# 640       641    2/9/2023   Vadapav  Fastfood          20        15
# 669       670    7/5/2022  Panipuri  Fastfood          20        15
# 718       719    5/9/2022   Vadapav  Fastfood          20        15
# 721       722   9/14/2022   Vadapav  Fastfood          20        15
#
#      transaction_amount transaction_type received_by time_of_sale
# 1                   300             Cash         Mr.    Afternoon
# ...

# %%
print("this is 10 top of quantity with high price")
data[data['quantity']==15].sort_values(by='item_price',ascending=False)[:10]
# Out:
# this is 10 top of quantity with high price
#      order_id        date item_name item_type  item_price  quantity  \
# 571       572    4/2/2022  Sandwich  Fastfood          60        15
# 137       138    9/1/2022  Sandwich  Fastfood          60        15
# 893       894   3/19/2023  Sandwich  Fastfood          60        15
# 491       492   7/11/2022  Sandwich  Fastfood          60        15
# 476       477   2/13/2023  Sandwich  Fastfood          60        15
# 360       361   6/30/2022  Sandwich  Fastfood          60        15
# 585       586   5/22/2022  Sandwich  Fastfood          60        15
# 905       906    4/4/2022  Sandwich  Fastfood          60        15
# 624       625   6/17/2022  Sandwich  Fastfood          60        15
# 543       544  12/14/2022  Sandwich  Fastfood          60        15
#
#      transaction_amount transaction_type received_by time_of_sale
# 571                 900             Cash         Mr.    Afternoon
# ...

# %%
data[data['item_type']=='Fastfood']
# Out:
#      order_id        date item_name item_type  item_price  quantity  \
# 0           1    7/3/2022  Aalopuri  Fastfood          20        13
# 1           2   8/23/2022   Vadapav  Fastfood          20        15
# 2           3  11/20/2022   Vadapav  Fastfood          20         1
# 5           6  11/14/2022   Vadapav  Fastfood          20        10
# 7           8  12/22/2022  Panipuri  Fastfood          20        14
# ..        ...         ...       ...       ...         ...       ...
# 995       996   3/19/2023   Frankie  Fastfood          50        10
# 996       997   9/20/2022  Sandwich  Fastfood          60         7
# 997       998   1/26/2023  Sandwich  Fastfood          60        13
# 998       999   8/27/2022  Panipuri  Fastfood          20         5
# 999      1000   5/29/2022  Aalopuri  Fastfood          20         3
#
#      transaction_amount transaction_type received_by time_of_sale
# 0                   260          Another         Mr.        Night
# ...

# %%
data[data['item_type']=='Beverages']
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 3           4    2/3/2023  Sugarcane juice  Beverages          25         6
# 4           5   10/2/2022  Sugarcane juice  Beverages          25         8
# 6           7    5/3/2022  Sugarcane juice  Beverages          25         9
# 19         20   9/15/2022      Cold coffee  Beverages          40        10
# 20         21  12/21/2022      Cold coffee  Beverages          40        15
# ..        ...         ...              ...        ...         ...       ...
# 981       982   3/30/2023  Sugarcane juice  Beverages          25        14
# 982       983   3/17/2023      Cold coffee  Beverages          40        10
# 985       986   4/30/2022  Sugarcane juice  Beverages          25        13
# 988       989  10/11/2022      Cold coffee  Beverages          40        13
# 994       995   6/18/2022  Sugarcane juice  Beverages          25         1
#
# ...

# %%
data['transaction_type'].value_counts()
# Out:
# Cash       476
# Online     417
# Another    107
# Name: transaction_type, dtype: int64

# %%
data['transaction_type'].value_counts().plot(kind='bar')
plt.show()

# %%
data['transaction_type'].value_counts().plot(kind='pie',autopct="%1.1f%%")
# Out:
# <Axes: ylabel='transaction_type'>

# %%
data['received_by'].value_counts()
# Out:
# Mr.     512
# Mrs.    488
# Name: received_by, dtype: int64

# %%
data['received_by'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='received_by'>

# %%
data.groupby(['received_by']).sum()['quantity']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\2018005887.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['received_by']).sum()['quantity']
# received_by
# Mr.     4268
# Mrs.    3894
# Name: quantity, dtype: int64

# %%
data.groupby(['received_by']).sum()['quantity'].plot(kind='pie',autopct='%1.1f%%')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\1192271519.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['received_by']).sum()['quantity'].plot(kind='pie',autopct='%1.1f%%')
# <Axes: ylabel='quantity'>

# %%
data.groupby(['transaction_type']).sum()['quantity']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\916517974.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['transaction_type']).sum()['quantity']
# transaction_type
# Another     928
# Cash       3943
# Online     3291
# Name: quantity, dtype: int64

# %%
data['time_of_sale'].value_counts()
# Out:
# Night        205
# Afternoon    205
# Evening      201
# Midnight     199
# Morning      190
# Name: time_of_sale, dtype: int64

# %%
data.groupby(['time_of_sale']).sum()['quantity']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\2260808145.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['time_of_sale']).sum()['quantity']
# time_of_sale
# Afternoon    1714
# Evening      1540
# Midnight     1575
# Morning      1574
# Night        1759
# Name: quantity, dtype: int64

# %%
data.groupby(['time_of_sale']).sum()['item_price']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\706754439.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['time_of_sale']).sum()['item_price']
# time_of_sale
# Afternoon    6675
# Evening      6810
# Midnight     6340
# Morning      6255
# Night        7235
# Name: item_price, dtype: int64

# %%
data.groupby(['item_name']).sum()['item_price'].sort_values(ascending=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\4063368484.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['item_name']).sum()['item_price'].sort_values(ascending=True)
# item_name
# Aalopuri           2680
# Vadapav            2680
# Panipuri           3000
# Sugarcane juice    3825
# Cold coffee        6440
# Frankie            6950
# Sandwich           7740
# Name: item_price, dtype: int64

# %%
data.groupby(['item_name']).sum()['quantity'].sort_values(ascending=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2620\3621458817.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['item_name']).sum()['quantity'].sort_values(ascending=True)
# item_name
# Vadapav            1006
# Aalopuri           1044
# Sandwich           1097
# Frankie            1150
# Panipuri           1226
# Sugarcane juice    1278
# Cold coffee        1361
# Name: quantity, dtype: int64

# %%
sns.countplot(x='transaction_type',hue='item_type',data=data)
# Out:
# <Axes: xlabel='transaction_type', ylabel='count'>

# %%
sns.countplot(x='transaction_type',hue='item_name',data=data)
# Out:
# <Axes: xlabel='transaction_type', ylabel='count'>

# %%
data
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1    7/3/2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4    2/3/2023  Sugarcane juice  Beverages          25         6
# 4           5   10/2/2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
data['quantity'].sum()
# Out:
# 8162

# %%
data['transaction_amount'].sum()
# Out:
# 275230

# %%
sns.pairplot(data)
